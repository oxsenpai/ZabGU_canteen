# %% [markdown]
# <a href="https://colab.research.google.com/github/oxsenpai/ZabGU_canteen/blob/main/%D0%94%D0%B0%D1%82%D0%B0%D1%84%D1%80%D0%B5%D0%B9%D0%BC%D1%8B_%D0%B8_%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Анализируем данные и строим графики

# %% [markdown]
# ### Библиотека Pandas

# %%
import pandas as pd

# %%
bank_db = {
    'Name' : ['Иван Иванович', 'Иван Петрович'],
    'Age' : [0, 1],
    'Experience' : [4, 7],
    'Salary' : [75, 95],
    'Credit_score' : [4, 8],
    'Outcome' : [0, 1]
}

# %%
df = pd.DataFrame(bank_db)

# %%
print(df)
# Out:
#             Name  Age  Experience  Salary  Credit_score  Outcome
# 0  Иван Иванович    0           4      75             4        0
# 1  Иван Петрович    1           7      95             8        1

# %%
# посчитаем средний доход заемщиков: (75 + 95) / 2
df['Salary'].mean()
# Out:
# 85.0

# %% [markdown]
# ### Библиотека Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# передаем функции plot() библиотеки Matplotlib два значения: доход и уровень счастья
x=[70, 80, 100, 150, 300]
y=[1, 4, 6, 9, 16]
plt.plot(x, y)

# добавим подписи для наглядности
plt.xlabel('Доход, тыс. рублей') # для оси x
plt.ylabel('Счастье, вымышленные единицы') # для оси y
plt.title('Счастье и уровень дохода') # заголовок

plt.show() # посмотрим, что у нас получилось

# %% [markdown]
# Корелляция - не означает причинно-следственную связь!![date.JPG](data:image/jpeg;base64,...)

# %%
# без plt.show()
plt.plot([70, 80, 100, 150, 300], [1, 4, 6, 9, 16])
plt.plot([39, 50, 80, 100, 200, 300], [1, 4, 7, 9, 18, 22])

# %%
# то же самое, но используя plt.show()
plt.plot([70, 80, 100, 150, 300], [1, 4, 6, 9, 16])
plt.show()
plt.plot([39, 50, 80, 100, 200, 300], [1, 4, 7, 9, 18, 22])
plt.show()

# %% [markdown]
# ### Упражнения

# %% [markdown]
# #### Библиотека Pandas

# %% [markdown]
# **Задание 1**. Еще раз импортируйте библиотеку pandas под псевдонимом pd.

# %%
import pandas as pd

# %% [markdown]
# **Задание 2**. Возьмите словарь с данными о заемщиках (см. выше bank_db), добавьте в него данные Алексея  и запишите получившийся словарь в переменную `new_bank_db`.

# %% [markdown]
# Алексей: возраст >30, стаж - 6 лет, доход-85, кредитная история -5

# %%
new_bank_db = {
    'Name' : ['Иван Иванович', 'Иван Петрович', 'Алексей'],
    'Age' : [0, 1, 1],
    'Experience' : [4, 7, 6],
    'Salary' : [75, 95, 85],
    'Credit_score' : [4, 8, 5],
    'Outcome' : [0, 1, 1]
}

# %% [markdown]
# **Задание 3**. Преобразуйте словарь в датафрейм и выведите результат.

# %%
newdf = pd.DataFrame(new_bank_db)

# %% [markdown]
# **Задание 4**. Вновь посчитайте средний доход заемщиков, изменился ли средний доход?

# %%
newdf['Salary'].mean()
# Out:
# 85.0

# %% [markdown]
# #### Библиотека Matplotlib

# %% [markdown]
# **Задание 5**. Еще раз импортируйте модуль pyplot из библиотеки Matplotlib под псевдонимом plt.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Задание 6**. Постройте график отражающий время ходьбы в минутах и количество потраченных калорий. Воспользуйтесь приведенными ниже списками для минут и калорий соответственно. Не забудьте про заголовок графика, а также подписи к каждой из осей.

# %%
minutes = [26, 42, 82]
calories = [138, 229, 445]

plt.plot(minutes, calories)

plt.xlabel('время ходьбы в минутах')
plt.ylabel('потраченные калории')
plt.title('график отражающий время ходьбы в минутах и количество потраченных калорий')

plt.show()
