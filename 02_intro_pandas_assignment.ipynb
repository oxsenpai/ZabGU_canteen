# %% [markdown]
# <a href="https://colab.research.google.com/github/oxsenpai/ZabGU_canteen/blob/main/02_intro_pandas_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('drive/My Drive/kaggle_survey_2022_responses.csv')
# Out:
# <ipython-input-10-4f95a9242816>:1: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('drive/My Drive/kaggle_survey_2022_responses.csv')

# %%
data.head(5)
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    121                        30-34
# 2                    462                        30-34
# 3                    293                        18-21
# 4                    851                        55-59
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
# 3                                      Egypt
# 4                                     France
#
#                                                   Q5  \
# 0  Are you currently a student? (high school, uni...
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#                                                 Q6_1  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
# 3                                           Coursera
# 4                                           Coursera
#
#                                                 Q6_2  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
# 3                                                edX
# 4                                                NaN
#
#                                                 Q6_3  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                               Kaggle Learn Courses
#
#                                                 Q6_4  \
# 0  On which platforms have you begun or completed...
# 1                                                NaN
# 2                                                NaN
# 3                                           DataCamp
# 4                                                NaN
#
#                                                 Q6_5  ...  \
# 0  On which platforms have you begun or completed...  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#                                                Q44_3  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                Q44_4  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                    Kaggle (notebooks, forums, etc)
# 4                    Kaggle (notebooks, forums, etc)
#
#                                                Q44_5  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Course Forums (forums.fast.ai, Coursera forums...
#
#                                                Q44_6  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 4                                                NaN
#
#                                                Q44_7  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 4                                                NaN
#
#                                                Q44_8  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Blogs (Towards Data Science, Analytics Vidhya,...
#
#                                                Q44_9  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Q44_10  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Q44_11  \
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               Q44_12
# 0  Who/what are your favorite media sources that ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 296 columns]

# %% [markdown]
# Узнай самый часто встречаемый возраст респондентов

# %%
data['Q2'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1a1dac911a11> in <cell line: 1>()
# ----> 1 data['Q2'].value_counts().type()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'

# %% [markdown]
# ## Task 2

# %% [markdown]
# Посчитай долю женщин среди русских участников опроса, которые уже не студенты. Результат округли до двух цифр после запятой

# %%
data[
    data['Q3'].str.contains('Woman') &
    data['Q4'].str.contains('Russia') &
    data['Q5'].str.contains('No')
].
# Out:
#       Duration (in seconds)     Q2     Q3      Q4  Q5      Q6_1 Q6_2  \
# 1333                   4218  55-59  Woman  Russia  No       NaN  NaN
# 1938                 162319  22-24  Woman  Russia  No  Coursera  NaN
# 1955                    794  25-29  Woman  Russia  No  Coursera  edX
# 3866                    524  30-34  Woman  Russia  No       NaN  NaN
# 3980                    336  30-34  Woman  Russia  No       NaN  NaN
# 4057                    931  30-34  Woman  Russia  No  Coursera  NaN
# 6772                    581  25-29  Woman  Russia  No  Coursera  NaN
# 8293                   2003  25-29  Woman  Russia  No       NaN  NaN
# 9210                    281  40-44  Woman  Russia  No  Coursera  NaN
# 9856                    590  22-24  Woman  Russia  No       NaN  NaN
# 10382                   263  30-34  Woman  Russia  No  Coursera  NaN
# 10813                 84793  30-34  Woman  Russia  No       NaN  NaN
# 11765                  1670  30-34  Woman  Russia  No       NaN  NaN
# 11902                   938  22-24  Woman  Russia  No  Coursera  NaN
# 12395                   608  30-34  Woman  Russia  No       NaN  NaN
# 13213                   157  30-34  Woman  Russia  No       NaN  NaN
# 13543                   631  22-24  Woman  Russia  No  Coursera  NaN
# 13829                   215  25-29  Woman  Russia  No  Coursera  edX
# 14215                   335  40-44  Woman  Russia  No       NaN  NaN
# 15072                  1050  22-24  Woman  Russia  No       NaN  NaN
# 15562                   525  35-39  Woman  Russia  No       NaN  NaN
# 16207                   135  35-39  Woman  Russia  No       NaN  NaN
# 16418                  1351  30-34  Woman  Russia  No       NaN  NaN
# 16589                   780  45-49  Woman  Russia  No       NaN  NaN
# 16783                   727  30-34  Woman  Russia  No  Coursera  NaN
# 16896                   153  30-34  Woman  Russia  No       NaN  NaN
# 18100                   379  40-44  Woman  Russia  No  Coursera  edX
# 18119                   373  30-34  Woman  Russia  No       NaN  NaN
# 18940                   181  40-44  Woman  Russia  No       NaN  NaN
# 19203                   534  22-24  Woman  Russia  No  Coursera  NaN
# 19546                 14651  30-34  Woman  Russia  No       NaN  NaN
# 19800                   281  22-24  Woman  Russia  No  Coursera  NaN
# 19902                   451  30-34  Woman  Russia  No       NaN  NaN
# 21074                   959  60-69  Woman  Russia  No       NaN  NaN
# 21174                   806  22-24  Woman  Russia  No  Coursera  NaN
# 21551                  1127  30-34  Woman  Russia  No       NaN  NaN
# 22877                   664  25-29  Woman  Russia  No  Coursera  NaN
# 23154                   380  25-29  Woman  Russia  No       NaN  NaN
# 23228                   928  45-49  Woman  Russia  No       NaN  NaN
#
#                        Q6_3      Q6_4 Q6_5  ...  \
# 1333                    NaN       NaN  NaN  ...
# 1938                    NaN       NaN  NaN  ...
# 1955   Kaggle Learn Courses       NaN  NaN  ...
# 3866   Kaggle Learn Courses       NaN  NaN  ...
# 3980                    NaN       NaN  NaN  ...
# 4057                    NaN       NaN  NaN  ...
# 6772   Kaggle Learn Courses       NaN  NaN  ...
# 8293                    NaN       NaN  NaN  ...
# 9210   Kaggle Learn Courses       NaN  NaN  ...
# 9856                    NaN       NaN  NaN  ...
# 10382                   NaN       NaN  NaN  ...
# 10813                   NaN       NaN  NaN  ...
# 11765                   NaN       NaN  NaN  ...
# 11902  Kaggle Learn Courses       NaN  NaN  ...
# 12395                   NaN       NaN  NaN  ...
# 13213                   NaN       NaN  NaN  ...
# 13543                   NaN       NaN  NaN  ...
# 13829  Kaggle Learn Courses       NaN  NaN  ...
# 14215                   NaN       NaN  NaN  ...
# 15072                   NaN       NaN  NaN  ...
# 15562                   NaN       NaN  NaN  ...
# 16207                   NaN       NaN  NaN  ...
# 16418  Kaggle Learn Courses       NaN  NaN  ...
# 16589                   NaN       NaN  NaN  ...
# 16783                   NaN       NaN  NaN  ...
# 16896  Kaggle Learn Courses       NaN  NaN  ...
# 18100  Kaggle Learn Courses       NaN  NaN  ...
# 18119                   NaN       NaN  NaN  ...
# 18940                   NaN       NaN  NaN  ...
# 19203                   NaN  DataCamp  NaN  ...
# 19546  Kaggle Learn Courses       NaN  NaN  ...
# 19800                   NaN       NaN  NaN  ...
# 19902                   NaN       NaN  NaN  ...
# 21074                   NaN       NaN  NaN  ...
# 21174                   NaN       NaN  NaN  ...
# 21551                   NaN       NaN  NaN  ...
# 22877                   NaN       NaN  NaN  ...
# 23154                   NaN       NaN  NaN  ...
# 23228                   NaN       NaN  NaN  ...
#
#                                  Q44_3                            Q44_4  \
# 1333                               NaN  Kaggle (notebooks, forums, etc)
# 1938                               NaN                              NaN
# 1955                               NaN                              NaN
# 3866                               NaN                              NaN
# 3980                               NaN                              NaN
# 4057                               NaN                              NaN
# 6772                               NaN  Kaggle (notebooks, forums, etc)
# 8293                               NaN                              NaN
# 9210                               NaN                              NaN
# 9856                               NaN                              NaN
# 10382                              NaN                              NaN
# 10813                              NaN                              NaN
# 11765                              NaN                              NaN
# 11902                              NaN  Kaggle (notebooks, forums, etc)
# 12395                              NaN                              NaN
# 13213                              NaN                              NaN
# 13543                              NaN  Kaggle (notebooks, forums, etc)
# 13829                              NaN  Kaggle (notebooks, forums, etc)
# 14215                              NaN                              NaN
# 15072                              NaN                              NaN
# 15562                              NaN                              NaN
# 16207                              NaN                              NaN
# 16418                              NaN                              NaN
# 16589                              NaN                              NaN
# 16783  Reddit (r/machinelearning, etc)  Kaggle (notebooks, forums, etc)
# 16896                              NaN                              NaN
# 18100                              NaN  Kaggle (notebooks, forums, etc)
# 18119                              NaN                              NaN
# 18940                              NaN                              NaN
# 19203                              NaN  Kaggle (notebooks, forums, etc)
# 19546                              NaN  Kaggle (notebooks, forums, etc)
# 19800                              NaN                              NaN
# 19902                              NaN                              NaN
# 21074                              NaN                              NaN
# 21174                              NaN                              NaN
# 21551                              NaN  Kaggle (notebooks, forums, etc)
# 22877                              NaN  Kaggle (notebooks, forums, etc)
# 23154                              NaN  Kaggle (notebooks, forums, etc)
# 23228                              NaN  Kaggle (notebooks, forums, etc)
#
#                                                    Q44_5  \
# 1333                                                 NaN
# 1938                                                 NaN
# 1955                                                 NaN
# 3866                                                 NaN
# 3980                                                 NaN
# 4057                                                 NaN
# 6772   Course Forums (forums.fast.ai, Coursera forums...
# 8293                                                 NaN
# 9210                                                 NaN
# 9856                                                 NaN
# 10382  Course Forums (forums.fast.ai, Coursera forums...
# 10813                                                NaN
# 11765  Course Forums (forums.fast.ai, Coursera forums...
# 11902  Course Forums (forums.fast.ai, Coursera forums...
# 12395                                                NaN
# 13213                                                NaN
# 13543                                                NaN
# 13829  Course Forums (forums.fast.ai, Coursera forums...
# 14215                                                NaN
# 15072                                                NaN
# 15562  Course Forums (forums.fast.ai, Coursera forums...
# 16207  Course Forums (forums.fast.ai, Coursera forums...
# 16418                                                NaN
# 16589                                                NaN
# 16783                                                NaN
# 16896                                                NaN
# 18100                                                NaN
# 18119                                                NaN
# 18940                                                NaN
# 19203                                                NaN
# 19546                                                NaN
# 19800                                                NaN
# 19902                                                NaN
# 21074  Course Forums (forums.fast.ai, Coursera forums...
# 21174  Course Forums (forums.fast.ai, Coursera forums...
# 21551  Course Forums (forums.fast.ai, Coursera forums...
# 22877                                                NaN
# 23154                                                NaN
# 23228  Course Forums (forums.fast.ai, Coursera forums...
#
#                                                    Q44_6  \
# 1333   YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1938   YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 1955                                                 NaN
# 3866                                                 NaN
# 3980                                                 NaN
# 4057                                                 NaN
# 6772   YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 8293                                                 NaN
# 9210                                                 NaN
# 9856   YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 10382  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 10813                                                NaN
# 11765                                                NaN
# 11902                                                NaN
# 12395  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 13213                                                NaN
# 13543                                                NaN
# 13829  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 14215                                                NaN
# 15072                                                NaN
# 15562  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 16207                                                NaN
# 16418  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 16589                                                NaN
# 16783                                                NaN
# 16896                                                NaN
# 18100  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 18119                                                NaN
# 18940                                                NaN
# 19203  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 19546  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 19800                                                NaN
# 19902                                                NaN
# 21074                                                NaN
# 21174  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 21551                                                NaN
# 22877  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23154  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
# 23228  YouTube (Kaggle YouTube, Cloud AI Adventures, ...
#
#                                                    Q44_7  \
# 1333                                                 NaN
# 1938                                                 NaN
# 1955                                                 NaN
# 3866                                                 NaN
# 3980                                                 NaN
# 4057                                                 NaN
# 6772                                                 NaN
# 8293                                                 NaN
# 9210                                                 NaN
# 9856                                                 NaN
# 10382                                                NaN
# 10813                                                NaN
# 11765                                                NaN
# 11902                                                NaN
# 12395                                                NaN
# 13213                                                NaN
# 13543                                                NaN
# 13829                                                NaN
# 14215                                                NaN
# 15072                                                NaN
# 15562                                                NaN
# 16207                                                NaN
# 16418  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 16589                                                NaN
# 16783                                                NaN
# 16896                                                NaN
# 18100                                                NaN
# 18119                                                NaN
# 18940                                                NaN
# 19203                                                NaN
# 19546                                                NaN
# 19800                                                NaN
# 19902                                                NaN
# 21074                                                NaN
# 21174  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 21551                                                NaN
# 22877  Podcasts (Chai Time Data Science, O’Reilly Dat...
# 23154                                                NaN
# 23228                                                NaN
#
#                                                    Q44_8  \
# 1333                                                 NaN
# 1938                                                 NaN
# 1955                                                 NaN
# 3866                                                 NaN
# 3980                                                 NaN
# 4057                                                 NaN
# 6772   Blogs (Towards Data Science, Analytics Vidhya,...
# 8293                                                 NaN
# 9210                                                 NaN
# 9856                                                 NaN
# 10382                                                NaN
# 10813                                                NaN
# 11765                                                NaN
# 11902                                                NaN
# 12395                                                NaN
# 13213                                                NaN
# 13543  Blogs (Towards Data Science, Analytics Vidhya,...
# 13829  Blogs (Towards Data Science, Analytics Vidhya,...
# 14215                                                NaN
# 15072                                                NaN
# 15562                                                NaN
# 16207                                                NaN
# 16418                                                NaN
# 16589                                                NaN
# 16783                                                NaN
# 16896                                                NaN
# 18100                                                NaN
# 18119                                                NaN
# 18940                                                NaN
# 19203  Blogs (Towards Data Science, Analytics Vidhya,...
# 19546  Blogs (Towards Data Science, Analytics Vidhya,...
# 19800                                                NaN
# 19902                                                NaN
# 21074                                                NaN
# 21174                                                NaN
# 21551  Blogs (Towards Data Science, Analytics Vidhya,...
# 22877  Blogs (Towards Data Science, Analytics Vidhya,...
# 23154                                                NaN
# 23228  Blogs (Towards Data Science, Analytics Vidhya,...
#
#                                                    Q44_9  \
# 1333                                                 NaN
# 1938                                                 NaN
# 1955                                                 NaN
# 3866                                                 NaN
# 3980                                                 NaN
# 4057   Journal Publications (peer-reviewed journals, ...
# 6772                                                 NaN
# 8293                                                 NaN
# 9210                                                 NaN
# 9856   Journal Publications (peer-reviewed journals, ...
# 10382                                                NaN
# 10813                                                NaN
# 11765                                                NaN
# 11902  Journal Publications (peer-reviewed journals, ...
# 12395                                                NaN
# 13213                                                NaN
# 13543  Journal Publications (peer-reviewed journals, ...
# 13829                                                NaN
# 14215                                                NaN
# 15072                                                NaN
# 15562                                                NaN
# 16207                                                NaN
# 16418                                                NaN
# 16589                                                NaN
# 16783                                                NaN
# 16896                                                NaN
# 18100                                                NaN
# 18119                                                NaN
# 18940                                                NaN
# 19203                                                NaN
# 19546                                                NaN
# 19800                                                NaN
# 19902                                                NaN
# 21074  Journal Publications (peer-reviewed journals, ...
# 21174                                                NaN
# 21551                                                NaN
# 22877                                                NaN
# 23154                                                NaN
# 23228  Journal Publications (peer-reviewed journals, ...
#
#                                              Q44_10 Q44_11 Q44_12
# 1333   Slack Communities (ods.ai, kagglenoobs, etc)    NaN    NaN
# 1938   Slack Communities (ods.ai, kagglenoobs, etc)    NaN    NaN
# 1955                                            NaN    NaN    NaN
# 3866                                            NaN    NaN    NaN
# 3980                                            NaN    NaN    NaN
# 4057                                            NaN    NaN    NaN
# 6772                                            NaN    NaN    NaN
# 8293                                            NaN    NaN    NaN
# 9210                                            NaN    NaN    NaN
# 9856                                            NaN    NaN    NaN
# 10382                                           NaN    NaN    NaN
# 10813                                           NaN    NaN    NaN
# 11765                                           NaN    NaN    NaN
# 11902                                           NaN    NaN    NaN
# 12395                                           NaN    NaN  Other
# 13213                                           NaN    NaN    NaN
# 13543                                           NaN    NaN    NaN
# 13829  Slack Communities (ods.ai, kagglenoobs, etc)    NaN    NaN
# 14215                                           NaN    NaN    NaN
# 15072                                           NaN    NaN    NaN
# 15562                                           NaN    NaN    NaN
# 16207                                           NaN    NaN    NaN
# 16418                                           NaN    NaN    NaN
# 16589  Slack Communities (ods.ai, kagglenoobs, etc)    NaN  Other
# 16783                                           NaN    NaN    NaN
# 16896                                           NaN    NaN    NaN
# 18100                                           NaN    NaN    NaN
# 18119                                           NaN   None    NaN
# 18940                                           NaN    NaN    NaN
# 19203                                           NaN    NaN    NaN
# 19546                                           NaN    NaN    NaN
# 19800                                           NaN    NaN    NaN
# 19902                                           NaN   None    NaN
# 21074                                           NaN    NaN    NaN
# 21174                                           NaN    NaN    NaN
# 21551                                           NaN    NaN    NaN
# 22877                                           NaN    NaN  Other
# 23154                                           NaN    NaN    NaN
# 23228                                           NaN    NaN    NaN
#
# [39 rows x 296 columns]

# %% [markdown]
# ## Task 3

# %% [markdown]
# Найди среднее время заполнения опроса в **минутах**. Результат округли до двух знаков после запятой

# %%
# Код тут

# %% [markdown]
# ## Task 4

# %% [markdown]
# Выведи топ-3 образовательных курса, которые указали респонденты. P.S Это вопрос Q6

# %%
# Код тут

# %% [markdown]
# ## Task 5

# %% [markdown]
# Узнай топ-5 языков программирования, которые регулярно используют Data Scientists в своей работе

# %%
# Код тут

# %% [markdown]
# ## Task 6

# %% [markdown]
# Узнай средний доход среди 'Data Scientist' специалистов и средний доход среди 'Machine Learning/ MLops Engineer' \
# Т.к. в колонке Q29 указан промежуток, то возьми среднее значение из промежутка.
#
# Например:
# - '15,000-19,999' - 17500,
# - '125,000-149,999' - 137500.
# - \> $1,000,000 - оставляем 1000000
#
# Средние доход **округли до целого.**

# %%
# Код тут

# %% [markdown]
# ## Дополнительно

# %% [markdown]
# Найди какой-нибудь интересный инсайт из этих данных.

# %%
# Код тут
